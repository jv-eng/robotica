# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import skfuzzy as fuzz

# %%
data = pd.read_csv("resultados_izq.csv")

# %%
#mostrar cabeceras
print("Cabecera: ")
print(data.head())
print()
# Out:
# Cabecera:
#    Semilla Aleatoria  Número de Individuos  Número de Generaciones  \
# 0                  0                     5                      10
# 1                  0                     5                      10
# 2                  0                     5                      10
# 3                  0                     5                      10
# 4                  0                     5                      10
#
#   Operador de Selección Operador de Cruce Operador de Mutación  \
# 0                Torneo           1 punto             Uniforme
# 1                Torneo           1 punto            Gaussiana
# 2                Torneo          2 puntos             Uniforme
# 3                Torneo          2 puntos            Gaussiana
# 4                Torneo           1 punto             Uniforme
#
#   Operador de Reemplazo  Tiempo de Simulación
# 0          Generacional             13.470834
# 1          Generacional             11.989796
# 2          Generacional             13.258334
# 3          Generacional             20.131579
# 4              Elitista             15.234375

# %%
print("Estadísticos: ")
print(data.describe())
print()
# Out:
# Estadísticos:
#        Semilla Aleatoria  Número de Individuos  Número de Generaciones  \
# count          96.000000             96.000000               96.000000
# mean           45.000000              6.500000               12.500000
# std            36.935221              1.507874                2.513123
# min             0.000000              5.000000               10.000000
# 25%             0.000000              5.000000               10.000000
# 50%            45.000000              6.500000               12.500000
# 75%            90.000000              8.000000               15.000000
# max            90.000000              8.000000               15.000000
#
#        Tiempo de Simulación
# count             96.000000
# mean              14.781755
# std                3.198388
# min                8.100000
# 25%               12.856971
# 50%               14.031250
# 75%               15.291234
# max               20.229885

# %%
data.groupby(['Operador de Cruce']).describe()
# Out:
#                   Semilla Aleatoria                                         \
#                               count  mean        std  min  25%   50%   75%
# Operador de Cruce
# 1 punto                        48.0  45.0  37.131165  0.0  0.0  45.0  90.0
# 2 puntos                       48.0  45.0  37.131165  0.0  0.0  45.0  90.0
#
#                         Número de Individuos       ... Número de Generaciones  \
#                     max                count mean  ...                    75%
# Operador de Cruce                                  ...
# 1 punto            90.0                 48.0  6.5  ...                   15.0
# 2 puntos           90.0                 48.0  6.5  ...                   15.0
#
#                         Tiempo de Simulación                                  \
#                     max                count       mean       std        min
# Operador de Cruce
# 1 punto            15.0                 48.0  14.795024  2.862504  11.057143
# 2 puntos           15.0                 48.0  14.768486  3.533091   8.100000
#
#
#                          25%        50%        75%        max
# Operador de Cruce
# 1 punto            13.051641  14.182165  15.150385  20.180180
# 2 puntos           12.800552  13.828748  17.031250  20.229885
#
# [2 rows x 32 columns]

# %%
data.groupby(['Operador de Mutación']).describe()
# Out:
#                      Semilla Aleatoria                                         \
#                                  count  mean        std  min  25%   50%   75%
# Operador de Mutación
# Gaussiana                         48.0  45.0  37.131165  0.0  0.0  45.0  90.0
# Uniforme                          48.0  45.0  37.131165  0.0  0.0  45.0  90.0
#
#                            Número de Individuos       ...  \
#                        max                count mean  ...
# Operador de Mutación                                  ...
# Gaussiana             90.0                 48.0  6.5  ...
# Uniforme              90.0                 48.0  6.5  ...
#
#                      Número de Generaciones       Tiempo de Simulación  \
#                                         75%   max                count
# Operador de Mutación
# Gaussiana                              15.0  15.0                 48.0
# Uniforme                               15.0  15.0                 48.0
#
#                                                                            \
#                            mean       std       min        25%        50%
# Operador de Mutación
# Gaussiana             13.867063  2.409808  9.827586  11.968162  13.539920
# Uniforme              15.696447  3.627798  8.100000  13.425729  14.378285
#
#
#                             75%        max
# Operador de Mutación
# Gaussiana             14.976724  20.165290
# Uniforme              20.138414  20.229885
#
# [2 rows x 32 columns]

# %%
data.groupby(['Operador de Reemplazo']).describe()
# Out:
#                       Semilla Aleatoria                                   \
#                                   count  mean        std  min  25%   50%
# Operador de Reemplazo
# Elitista                           48.0  45.0  37.131165  0.0  0.0  45.0
# Generacional                       48.0  45.0  37.131165  0.0  0.0  45.0
#
#                                   Número de Individuos       ...  \
#                         75%   max                count mean  ...
# Operador de Reemplazo                                        ...
# Elitista               90.0  90.0                 48.0  6.5  ...
# Generacional           90.0  90.0                 48.0  6.5  ...
#
#                       Número de Generaciones       Tiempo de Simulación  \
#                                          75%   max                count
# Operador de Reemplazo
# Elitista                                15.0  15.0                 48.0
# Generacional                            15.0  15.0                 48.0
#
#                                                                             \
#                             mean       std       min        25%        50%
# Operador de Reemplazo
# Elitista               14.617007  3.487869  8.100000  11.889567  13.935490
# Generacional           14.946503  2.907980  9.827586  13.159745  14.101078
#
#
#                              75%        max
# Operador de Reemplazo
# Elitista               15.925000  20.229885
# Generacional           15.152825  20.217084
#
# [2 rows x 32 columns]

# %%
data.groupby(['Semilla Aleatoria']).describe()
# Out:
#                   Número de Individuos                                     \
#                                  count mean       std  min  25%  50%  75%
# Semilla Aleatoria
# 0                                 32.0  6.5  1.524002  5.0  5.0  6.5  8.0
# 45                                32.0  6.5  1.524002  5.0  5.0  6.5  8.0
# 90                                32.0  6.5  1.524002  5.0  5.0  6.5  8.0
#
#                        Número de Generaciones        ...              \
#                    max                  count  mean  ...   75%   max
# Semilla Aleatoria                                    ...
# 0                  8.0                   32.0  12.5  ...  15.0  15.0
# 45                 8.0                   32.0  12.5  ...  15.0  15.0
# 90                 8.0                   32.0  12.5  ...  15.0  15.0
#
#                   Tiempo de Simulación                                 \
#                                  count       mean       std       min
# Semilla Aleatoria
# 0                                 32.0  14.820981  3.554093  8.100000
# 45                                32.0  15.222210  3.082043  9.827586
# 90                                32.0  14.302073  2.962953  8.350000
#
#
#                          25%        50%        75%        max
# Semilla Aleatoria
# 0                  11.954468  14.426692  16.456456  20.217084
# 45                 13.204945  14.047280  16.510065  20.229885
# 90                 12.563471  13.711144  15.100254  20.180180
#
# [3 rows x 24 columns]

# %%
data.groupby(['Número de Individuos']).describe()
# Out:
#                      Semilla Aleatoria                                         \
#                                  count  mean        std  min  25%   50%   75%
# Número de Individuos
# 5                                 48.0  45.0  37.131165  0.0  0.0  45.0  90.0
# 8                                 48.0  45.0  37.131165  0.0  0.0  45.0  90.0
#
#                            Número de Generaciones        ...              \
#                        max                  count  mean  ...   75%   max
# Número de Individuos                                     ...
# 5                     90.0                   48.0  12.5  ...  15.0  15.0
# 8                     90.0                   48.0  12.5  ...  15.0  15.0
#
#                      Tiempo de Simulación                             \
#                                     count       mean       std   min
# Número de Individuos
# 5                                    48.0  14.950278  3.389957  8.35
# 8                                    48.0  14.613232  3.021126  8.10
#
#
#                             25%        50%        75%        max
# Número de Individuos
# 5                     12.856971  14.143935  17.000000  20.229885
# 8                     12.808465  13.935490  15.108423  20.217084
#
# [2 rows x 24 columns]

# %%
data.groupby(['Número de Generaciones']).describe()
# Out:
#                        Semilla Aleatoria                                   \
#                                    count  mean        std  min  25%   50%
# Número de Generaciones
# 10                                  48.0  45.0  37.131165  0.0  0.0  45.0
# 15                                  48.0  45.0  37.131165  0.0  0.0  45.0
#
#                                    Número de Individuos       ...            \
#                          75%   max                count mean  ...  75%  max
# Número de Generaciones                                        ...
# 10                      90.0  90.0                 48.0  6.5  ...  8.0  8.0
# 15                      90.0  90.0                 48.0  6.5  ...  8.0  8.0
#
#                        Tiempo de Simulación                             \
#                                       count       mean       std   min
# Número de Generaciones
# 10                                     48.0  14.474674  2.992191  8.10
# 15                                     48.0  15.088835  3.395762  8.35
#
#
#                               25%        50%        75%        max
# Número de Generaciones
# 10                      12.570979  14.160382  15.150385  20.229885
# 15                      13.044321  13.976667  20.030675  20.217084
#
# [2 rows x 24 columns]

# %%
#menor tiempo
filas_menor_tiempo = data.nsmallest(5, "Tiempo de Simulación")
print("Combinaciones con menor tiempo de ejecución")
print(filas_menor_tiempo)
# Out:
# Combinaciones con menor tiempo de ejecución
#     Semilla Aleatoria  Número de Individuos  Número de Generaciones  \
# 22                  0                     8                      10
# 78                 90                     5                      15
# 6                   0                     5                      10
# 43                 45                     5                      15
# 31                  0                     8                      15
#
#    Operador de Selección Operador de Cruce Operador de Mutación  \
# 22                Torneo          2 puntos             Uniforme
# 78                Torneo          2 puntos             Uniforme
# 6                 Torneo          2 puntos             Uniforme
# 43                Torneo          2 puntos            Gaussiana
# 31                Torneo          2 puntos            Gaussiana
#
#    Operador de Reemplazo  Tiempo de Simulación
# 22              Elitista              8.100000
# 78              Elitista              8.350000
# 6               Elitista              9.650000
# 43          Generacional              9.827586
# 31              Elitista             10.800000

# %%
filas_menor_tiempo.iloc[0]
# Out:
# Semilla Aleatoria                0
# Número de Individuos             8
# Número de Generaciones          10
# Operador de Selección       Torneo
# Operador de Cruce         2 puntos
# Operador de Mutación      Uniforme
# Operador de Reemplazo     Elitista
# Tiempo de Simulación           8.1
# Name: 22, dtype: object

# %%
#escenario esfera centrada
vect = [24.343712756485537, 78.99857204111139, 117.54432894919336, 137.5986499362459, 167.33353343089132, 176.34127573923632, 197.61402533181743, 230.03141038123883]	
datos = np.arange(0, 256, 0.1)

plt.subplot(3, 1, 1)
plt.plot(datos, fuzz.trapmf(datos, [0, 0, vect[0], vect[1]]), 'b', linewidth=1.5, label='muy izq')
plt.plot(datos, fuzz.trapmf(datos, [vect[0], vect[1], vect[2], vect[3]]), 'g', linewidth=1.5, label='izq')
plt.plot(datos, fuzz.trapmf(datos, [vect[2], vect[3], vect[4], vect[5]]), 'k', linewidth=1.5, label='centrado')
plt.plot(datos, fuzz.trapmf(datos, [vect[4], vect[5], vect[6], vect[7]]), 'r', linewidth=1.5, label='dcha')
plt.plot(datos, fuzz.trapmf(datos, [vect[6], vect[7], 256, 256]), 'm', linewidth=1.5, label='muy dcha')
plt.title('Error actual')
plt.xlabel('Valor')
plt.ylabel('Membresía')
plt.legend()
plt.tight_layout()
plt.show()
